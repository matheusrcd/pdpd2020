# %%
# %matplotlib inline
import pylhe
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['figure.figsize'] = [14, 3]

# LHE File for "p p > H  j, H > S S - MS= 55Gev BR = 17% ptj = 500"
lhe_MS55 = pylhe.readLHE("Events/with_ptj500/run_ssj_MDM55/unweighted_events.lhe")

# LHE File for "p p > S S j - MS= 250Gev LHS = 12 ptj = 500"
lhe_MS250 = pylhe.readLHE("Events/with_ptj500/run_ssj_MDM250/unweighted_events.lhe")

# LHE File for "p p > S S j - MS= 500Gev LHS = 12 ptj = 500"
lhe_MS500 = pylhe.readLHE("Events/with_ptj500/run_ssj_MDM500/unweighted_events.lhe")

# LHE File for "p p > Z j, Z > vl vl~  ptj = 500"
lhe_zj= pylhe.readLHE("Events/with_ptj500/run_zvlvl/unweighted_events.lhe")

# LHE File for "p p > Z j, Z > vl vl~ "
lhe_zj_nocut= pylhe.readLHE("Events/run_zvlvl_50000/unweighted_events.lhe")



def momenta(particles, transverse=False):
    total_momentum = 0
    p = [0, 0, 0]
    for ptc in particles:
        p[0] += ptc.px
        p[1] += ptc.py
        p[2] += ptc.pz

    if transverse == True:
        transverse_momentum = np.sqrt(p[0]**2 + p[1]**2)
        return transverse_momentum

    total_momentum = np.sqrt(p[0]**2 + p[1]**2 + p[2]**2)
    return total_momentum

def invariant_mass(event, p_ids):
    matter = []
    e_total = [] 
    for ptc in event.particles:
        if ptc.id in p_ids:
            matter.append(ptc)
            e_total.append(ptc.e)
    return np.sqrt(sum(e_total)**2 - momenta(matter)**2)

def transverse_momentum(event, p_ids):
    matter = []
    for ptc in event.particles:
        if ptc.status > 0 and abs(ptc.id) in p_ids:
            matter.append(ptc)
    return momenta(matter, transverse=True)


jet_ids = [1, 2, 3, 4, 5, 6, 21]

# %%
plt.rcParams['figure.figsize'] = [14, 8]
ms55_transverse_momentum = []
wms55 = [3.2056895913780002]*100000
for event in lhe_MS55:
    pt = transverse_momentum(event, jet_ids)
    ms55_transverse_momentum.append(pt)

wms250 = [0.36284411760957]*100000
ms250_transverse_momentum = []
for event in lhe_MS250:
    pt = transverse_momentum(event, jet_ids)
    ms250_transverse_momentum.append(pt)

wms500 = [1.7573345239750998e-02]*100000
ms500_transverse_momentum = []
for event in lhe_MS500:
    pt = transverse_momentum(event, jet_ids)
    ms500_transverse_momentum.append(pt)

wzj = [170.54664000000003]*100000
zj_transverse_momentum = []
for event in lhe_zj:
    pt = transverse_momentum(event, jet_ids)
    zj_transverse_momentum.append(pt)

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
bins = range(500, 3400, 100)

# histogram for "p p > H  j, H > S S - MS= 55Gev"
ax1.hist(ms55_transverse_momentum, bins = bins, alpha=0.8, color='blue', label='MS = 55Gev', log=True, edgecolor='black')
ax1.set(xlabel='Momentum (Gev)', ylabel='N Events')
ax1.legend()

# histogram for "p p > H  j, H > S S - MS= 250Gev"
ax2.hist(ms250_transverse_momentum, bins = bins, alpha=0.8, color='red', label='MS = 250Gev', log=True, edgecolor='black')
ax2.set(xlabel='Momentum (Gev)', ylabel='N Events')
ax2.legend()

# histogram for "p p > Z j, Z > trvl vl~ "
ax3.hist(zj_transverse_momentum, bins = bins, alpha=0.8, color='orange', label='ppzj', log=True, edgecolor='black')
ax3.set(xlabel='Momentum (Gev)', ylabel='N Events')
ax3.legend()

# histogram for "p p > H  j, H > S S and p p > Z j, Z > vl vl~ "
ax4.hist(ms55_transverse_momentum, bins = bins, alpha=0.6, color='blue', label='MS = 55Gev', log=True, edgecolor='blue',
histtype='step', weights= wms55 )
ax4.hist(ms250_transverse_momentum, bins = bins, alpha=0.6, color='red', label='MS = 250Gev', log=True, edgecolor='red',histtype='step', weights= wms250)
ax4.hist(ms500_transverse_momentum, bins = bins, alpha=0.6, color='m', label='MS = 500Gev', log=True, edgecolor='m', histtype='step', weights= wms500)
ax4.hist(zj_transverse_momentum, bins = bins, alpha=0.6, color='orange', label='ppzj', log=True, edgecolor='orange', histtype='step', weights= wzj)
ax4.set(xlabel='Momentum (Gev)', ylabel='N Events')
ax4.legend()

fig.suptitle('Jet Transverse Momentum')
fig.tight_layout()
plt.show()

# %%
plt.rcParams['figure.figsize'] = [14, 8]
ms55_transverse_momentum = []
wms55 = [3.2056895913780002]*100000
for event in lhe_MS55:
    pt = transverse_momentum(event, jet_ids)
    ms55_transverse_momentum.append(pt)

wms250 = [0.36284411760957]*100000
ms250_transverse_momentum = []
for event in lhe_MS250:
    pt = transverse_momentum(event, jet_ids)
    ms250_transverse_momentum.append(pt)

wms500 = [1.7573345239750998e-02]*100000
ms500_transverse_momentum = []
for event in lhe_MS500:
    pt = transverse_momentum(event, jet_ids)
    ms500_transverse_momentum.append(pt)

wzj = [170.54664000000003]*100000
zj_transverse_momentum = []
for event in lhe_zj:
    pt = transverse_momentum(event, jet_ids)
    zj_transverse_momentum.append(pt)

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
bins = range(500, 3400, 100)

# histogram for "p p > H  j, H > S S - MS= 55Gev"
ax1.hist(ms55_transverse_momentum, bins = bins, alpha=0.8, color='blue', label='MS = 55Gev', log=True, edgecolor='black')
ax1.set(xlabel='Momentum (Gev)', ylabel='N Events')
ax1.legend()

# histogram for "p p > H  j, H > S S - MS= 250Gev"
ax2.hist(ms250_transverse_momentum, bins = bins, alpha=0.8, color='red', label='MS = 250Gev', log=True, edgecolor='black')
ax2.set(xlabel='Momentum (Gev)', ylabel='N Events')
ax2.legend()

# histogram for "p p > Z j, Z > trvl vl~ "
ax3.hist(zj_transverse_momentum, bins = bins, alpha=0.8, color='orange', label='ppzj', log=True, edgecolor='black')
ax3.set(xlabel='Momentum (Gev)', ylabel='N Events')
ax3.legend()

# histogram for "p p > H  j, H > S S and p p > Z j, Z > vl vl~ "
ns_ms55, bins_ms55, patches_ms55 = ax4.hist(ms55_transverse_momentum, bins = bins, alpha=0.6, color='blue', label='MS = 55Gev', log=True, edgecolor='blue',
histtype='step', weights= wms55 )
ax4.hist(ms250_transverse_momentum, bins = bins, alpha=0.6, color='red', label='MS = 250Gev', log=True, edgecolor='red',histtype='step', weights= wms250)
ns_ms500, bins_ms500, patches_ms500 = ax4.hist(ms500_transverse_momentum, bins = bins, alpha=0.6, color='m', label='MS = 500Gev', log=True, edgecolor='m', histtype='step', weights= wms500)
ns_z, bins_z, patches_z = ax4.hist(zj_transverse_momentum, bins = bins, alpha=0.6, color='orange', label='ppzj', log=True, edgecolor='orange', histtype='step', weights= wzj)
ax4.set(xlabel='Momentum (Gev)', ylabel='N Events')
ax4.legend()

# histogram for the ratio ms55/ppzj
ns_ratio = []

for i, val in enumerate(ns_ms55):
    if ns_z[i] != 0:
        ns_ratio.append(val/ns_z[i])
    else:
        ns_ratio.append(0.0)
ns_ratio.append(0.0)


vls5p =[]
c = 0
for i, value in enumerate(ns_ratio):
    if value >= 0.05:
        vls5p.append([value])
        vls5p[c].append(bins_ms55[i])
        c+=1
print(vls5p)
######
ns_ratio = []

for i, val in enumerate(ns_ms500):
    if ns_z[i] != 0:
        ns_ratio.append(val/ns_z[i])
    else:
        ns_ratio.append(0.0)
ns_ratio.append(0.0)


vls5p =[]
c = 0
for i, value in enumerate(ns_ratio):
    if value >= 0.05:
        vls5p.append([value])
        vls5p[c].append(bins_ms500[i])
        c+=1
print(vls5p)

fig.suptitle('Jet Transverse Momentum')
fig.tight_layout()
plt.show()
# Out:
# [[0.05082032000845474, 1300], [0.050053752152397865, 1400], [0.07176867109533412, 1500], [0.0545706485287496, 1600], [0.07518622686196523, 1800], [0.08270484954798109, 1900], [0.12531037810281917, 2000], [0.2255586805834322, 2100], [0.05638967014647392, 2200]]
# []

# %%
plt.rcParams['figure.figsize'] = [14, 8]
ms55_transverse_momentum = []
wms55 = [3.2056895913780002]*100000
for event in lhe_MS55:
    pt = transverse_momentum(event, jet_ids)
    ms55_transverse_momentum.append(pt)

wms250 = [0.36284411760957]*100000
ms250_transverse_momentum = []
for event in lhe_MS250:
    pt = transverse_momentum(event, jet_ids)
    ms250_transverse_momentum.append(pt)

wms500 = [1.7573345239750998e-02]*100000
ms500_transverse_momentum = []
for event in lhe_MS500:
    pt = transverse_momentum(event, jet_ids)
    ms500_transverse_momentum.append(pt)

wzj = [2233475]*50000
zj_transverse_momentum = []
for event in lhe_zj_nocut:
    pt = transverse_momentum(event, jet_ids)
    zj_transverse_momentum.append(pt)

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
bins = range(500, 3400, 100)

# histogram for "p p > H  j, H > S S - MS= 55Gev"
ax1.hist(ms55_transverse_momentum, bins = bins, alpha=0.8, color='blue', label='MS = 55Gev', log=True, edgecolor='black')
ax1.set(xlabel='Momentum (Gev)', ylabel='N Events')
ax1.legend()

# histogram for "p p > H  j, H > S S - MS= 250Gev"
ax2.hist(ms250_transverse_momentum, bins = bins, alpha=0.8, color='red', label='MS = 250Gev', log=True, edgecolor='black')
ax2.set(xlabel='Momentum (Gev)', ylabel='N Events')
ax2.legend()

# histogram for "p p > Z j, Z > trvl vl~ "
ax3.hist(zj_transverse_momentum, bins = bins, alpha=0.8, color='orange', label='ppzj', log=True, edgecolor='black')
ax3.set(xlabel='Momentum (Gev)', ylabel='N Events')

# histogram for "p p > H  j, H > S S and p p > Z j, Z > vl vl~ "
ax4.hist(ms55_transverse_momentum, bins = bins, alpha=0.6, color='blue', label='MS = 55Gev', log=True, edgecolor='blue',
histtype='step', weights= wms55 )
ax4.hist(ms250_transverse_momentum, bins = bins, alpha=0.6, color='red', label='MS = 250Gev', log=True, edgecolor='red',histtype='step', weights= wms250)
ax4.hist(ms500_transverse_momentum, bins = bins, alpha=0.6, color='m', label='MS = 500Gev', log=True, edgecolor='m', histtype='step', weights= wms500)
ax4.hist(zj_transverse_momentum, bins = bins, alpha=0.6, color='orange', label='ppzj', log=True, edgecolor='orange', histtype='step', weights= wzj)
ax4.set(xlabel='Momentum (Gev)', ylabel='N Events')
ax4.legend()

fig.suptitle('Jet Transverse Momentum')
fig.tight_layout()
plt.show()
