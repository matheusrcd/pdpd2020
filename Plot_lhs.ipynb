# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from math import e

plt.rcParams['figure.figsize'] = [14, 5]

# %%
x_hss = [1, 30, 55, 60, 62]
y_hss = [0.02, 0.022, 0.026, 0.035, 0.055]
x_ppss = np.linspace(62, 210)

plt.plot(x_hss, y_hss, linewidth=6)
plt.plot(x_ppss, x_ppss*0 + 12, linewidth=6)

x_excld800 = []
y_exlcd800 = []
max_lhs =[(1.0, 0.03308441765543877), (10.0, 0.03324056646159267), (20.0, 0.03376103661079939), (30.0, 0.0347735571592), (40.0, 0.03664341800631927), (50.0, 0.04053509645558583), (55.0, 0.044795041197097415), (60.0, 0.056744929133182284), (62.0, 0.08254812400424255), (62.5, 0.4260665653283286), (63.0, 2.079982463834604), (65.0, 3.451797260287433), (70.0, 5.234280563100478), (75.0, 6.564916560796594), (90.0, 9.910825017476057), (100.0, 11.981216134076654), (120.0, 16.12779312177265), (150.0, 22.746525749463743), (180.0, 30.094818990931447), (200.0, 35.52609543269335)]
for pair in max_lhs:
    x_excld800.append(pair[0])
    y_exlcd800.append(pair[1])
plt.plot(x_excld800, y_exlcd800, linewidth=2, color='r')

plt.gca().set_facecolor("#3b3b3b")
plt.yscale('log')
plt.axhspan(0, 12, facecolor='#7bc46a')
plt.axvspan(0, 62, facecolor='#3b3b3b')
plt.axhspan(0, 0.029, facecolor='#7bc46a')
plt.xlabel('Massa (Gev)')
plt.margins(y=1, x =0)
plt.ylabel('LHS')
plt.ylim(0.01,15)
plt.xlim()


plt.title("Acoplamento do higgs em função da massa de matéria escura (ptj = 800GeV)")

plt.show()

# %%
x_hss = [1, 30, 55, 60, 62]
y_hss = [0.02, 0.022, 0.026, 0.035, 0.055]
x_ppss = np.linspace(62, 210)

plt.plot(x_hss, y_hss, linewidth=6)
plt.plot(x_ppss, x_ppss*0 + 12, linewidth=6)

x_excld500 = []
y_exlcd500 = []
max_lhs = [(1.0, 0.046462875359363505), (10.0, 0.04669826261618208), (20.0, 0.04746186006883272), (30.0, 0.048943300565523554), (40.0, 0.05166734460952006), (50.0, 0.05739617594260513), (55.0, 0.06361428855220158), (60.0, 0.08089073847187467), (61.0, 0.09099142292464305), (62.5, 0.6118248165890465), (63.0, 2.71467695326363), (65.0, 4.5441655682580375), (70.0, 6.954196774964713), (75.0, 8.788232076689804), (90.0, 13.53323680174062), (110.0, 19.659662948199824), (130.0, 26.156516490150267), (150.0, 33.27791238108164), (180.0, 45.41006842282843), (200.0, 54.5916821896406)]
for pair in max_lhs:
    x_excld500.append(pair[0])
    y_exlcd500.append(pair[1])
plt.plot(x_excld500, y_exlcd500, linewidth=2, color='r')

plt.gca().set_facecolor("#3b3b3b")
plt.yscale('log')
plt.axhspan(0, 12, facecolor='#7bc46a')
plt.axvspan(0, 62, facecolor='#3b3b3b')
plt.axhspan(0, 0.029, facecolor='#7bc46a')
plt.xlabel('Massa (Gev)')
plt.margins(y=1, x =0)
plt.ylabel('LHS')
plt.ylim(0.01,15)

plt.title("Acoplamento do higgs em função da massa de matéria escura (ptj = 500GeV)")

plt.show()

# %%
x_hss = [1, 30, 55, 60, 62]
y_hss = [0.02, 0.022, 0.026, 0.035, 0.055]
x_ppss = np.linspace(62, 210)


plt.plot(x_hss, y_hss, linewidth=6)
plt.plot(x_ppss, x_ppss*0 + 12, linewidth=6)

x_excld1000 = []
y_exlcd1000 = []
max_lhs = [(1.0, 0.031549164430298565), (10.0, 0.03170967133908034), (20.0, 0.03222728851193443), (30.0, 0.03323561711565331), (40.0, 0.035091149503355505), (50.0, 0.0389801364499246), (55.0, 0.043192986297558036), (60.0, 0.054927011149090675), (61.0, 0.06179149325431483), (62.5, 0.4154790406960981), (63.0, 1.8372467064136062), (65.0, 3.0492513753299586), (70.0, 4.6084942371056545), (75.0, 5.760955490490191), (90.0, 8.643276114120976), (110.0, 12.157381463143896), (130.0, 15.68293874298919), (150.0, 19.37132327883472), (180.0, 25.365223382808537), (200.0, 29.67477006891425)]
for pair in max_lhs:
    x_excld1000.append(pair[0])
    y_exlcd1000.append(pair[1])
plt.plot(x_excld1000, y_exlcd1000, linewidth=2, color='r')

plt.gca().set_facecolor("#3b3b3b")
plt.yscale('log')
plt.axhspan(0, 12, facecolor='#7bc46a')
plt.axvspan(0, 62, facecolor='#3b3b3b')
plt.axhspan(0, 0.029, facecolor='#7bc46a')
plt.xlabel('Massa (Gev)')
plt.margins(y=1, x =0)
plt.ylabel('LHS')
plt.ylim(0.01,15)

plt.title("Acoplamento do higgs em função da massa de matéria escura (ptj = 1000)")

plt.show()

# %%
x_hss = [1, 30, 55, 60, 62]
y_hss = [0.02, 0.022, 0.026, 0.035, 0.055]
x_ppss = np.linspace(62, 210)


plt.plot(x_hss, y_hss, linewidth=6)
plt.plot(x_ppss, x_ppss*0 + 12, linewidth=6)


plt.plot(x_excld500, y_exlcd500, linewidth=2, color='r', label="Cut = 500GeV")
plt.plot(x_excld800, y_exlcd800, linewidth=2, color='g', label="Cut = 800GeV")
plt.plot(x_excld1000, y_exlcd1000, linewidth=2, color='b', label="Cut = 1000GeV")

plt.gca().set_facecolor("#3b3b3b")
plt.yscale('log')
plt.axhspan(0, 12, facecolor='#7bc46a')
plt.axvspan(0, 62, facecolor='#3b3b3b')
plt.axhspan(0, 0.029, facecolor='#7bc46a')
plt.xlabel('Massa (Gev)')
plt.margins(y=1, x =0)
plt.ylabel('LHS')
plt.ylim(0.02,30)

plt.title("Acoplamento do higgs em função da massa de matéria escura (ptj = 1000)")
plt.legend()
plt.show()
