# %%
# %matplotlib inline
import pylhe
import matplotlib.pyplot as plt
import numpy as np

# LHE File for "p p > Z  j, Z > vm vm~"
lhe_zjvv = pylhe.readLHE("Events/run_ppZjvmvm~/unweighted_events.lhe")

# LHE File for "p p > H  j, H > S S"
lhe_hjss = pylhe.readLHE("Events/run_pphjSS/unweighted_events.lhe")

# LHE File for "p p > H  j, H > S S LOWLHS"
lhe_hjss_lowLHS = pylhe.readLHE("Events/run_ppHjSS_lowLHS/unweighted_events.lhe")

# LHE File for "p p > H  j, H > S S HIGHWH"
lhe_hjss_highWH = pylhe.readLHE("Events/run_pphjss_highWH/unweighted_events.lhe")

# LHE File for "p p > H  j, H > S S HIGHMS"
lhe_hjss_highMS = pylhe.readLHE("Events/run_pphjSS_highMS/unweighted_events.lhe")

# LHE File for "p p > H  j, H > S S LOWMS"
lhe_hjss_lowMS = pylhe.readLHE("Events/run_pphjSS_lowMS/unweighted_events.lhe")

# %%
hj_transverse_momentum = []
for event in lhe_hjss:
    j = event.particles[-1]
    pt = np.sqrt(j.px**2 + j.py**2)
    hj_transverse_momentum.append(pt)

# histogram for "p p > H  j, H > S S"
plt.hist(hj_transverse_momentum, bins = 100)
plt.xlabel('Momentum (GeV)')
plt.ylabel('N Events')
plt.title('Transverse Momentum (p p > H  j, H > S S)', fontweight="bold")
plt.show()

# %%
zj_transverse_momentum = []
for event in lhe_zjvv:
    j = event.particles[-1]
    pt = np.sqrt(j.px**2 + j.py**2)
    zj_transverse_momentum.append(pt)

# histogram for "p p > Z  j, Z > vm vm~"
plt.hist(zj_transverse_momentum, bins = 100)
plt.xlabel('Momentum (GeV)')
plt.ylabel('N Events')
plt.title('Transverse Momentum (p p > Z  j, Z > vm vm~)', fontweight="bold")
plt.show()

# %%
lowLHS_transverse_momentum = []
for event in lhe_hjss_lowLHS:
    j = event.particles[-1]
    pt = np.sqrt(j.px**2 + j.py**2)
    lowLHS_transverse_momentum.append(pt)

# histogram for "p p > H  j, H > S S LOWLHS"
plt.hist(lowLHS_transverse_momentum, bins = 100)
plt.xlabel('Momentum (GeV)')
plt.ylabel('N Events')
plt.title('Transverse Momentum (p p > H  j, H > S S)', fontweight="bold")
plt.show()

# %%
highWH_transverse_momentum = []
for event in lhe_hjss_highWH:
    j = event.particles[-1]
    pt = np.sqrt(j.px**2 + j.py**2)
    highWH_transverse_momentum.append(pt)

# histogram for "p p > H  j, H > S S HIGHWH"
plt.hist(highWH_transverse_momentum, bins = 100)
plt.xlabel('Momentum (GeV)')
plt.ylabel('N Events')
plt.title('Transverse Momentum (p p > H  j, H > S S)', fontweight="bold")
plt.show()

# %%
highMS_transverse_momentum = []
for event in lhe_hjss_highMS:
    j = event.particles[-1]
    pt = np.sqrt(j.px**2 + j.py**2)
    highMS_transverse_momentum.append(pt)

# histogram for "p p > H  j, H > S S HIGHMS"
plt.hist(highMS_transverse_momentum, bins = 100)
plt.xlabel('Momentum (GeV)')
plt.ylabel('N Events')
plt.title('Transverse Momentum (p p > H  j, H > S S)', fontweight="bold")
plt.show()

# %%
lowMS_transverse_momentum = []
for event in lhe_hjss_lowMS:
    j = event.particles[-1]
    pt = np.sqrt(j.px**2 + j.py**2)
    lowMS_transverse_momentum.append(pt)

# histogram for "p p > H  j, H > S S LOWMS"
plt.hist(lowMS_transverse_momentum, bins = 100)
plt.xlabel('Momentum (GeV)')
plt.ylabel('N Events')
plt.title('Transverse Momentum (p p > H  j, H > S S)', fontweight="bold")
plt.show()

# %%
highMS_transverse_momentum = []
for event in lhe_hjss_highMS:
    j = event.particles[-1]
    pt = np.sqrt(j.px**2 + j.py**2)
    highMS_transverse_momentum.append(pt)

lowMS_transverse_momentum = []
for event in lhe_hjss_lowMS:
    j = event.particles[-1]
    pt = np.sqrt(j.px**2 + j.py**2)
    lowMS_transverse_momentum.append(pt)

bins = range(0, 601, 40)

# histogram for "p p > H  j, H > S S LOWMS"
plt.hist(lowMS_transverse_momentum, bins = bins, alpha=0.5, color='red', label='MS = 1GeV', edgecolor='black')

# histogram for "p p > H  j, H > S S HIGHMS"
plt.hist(highMS_transverse_momentum, bins = bins, alpha=0.5, color='blue', label='MS = 62GeV', edgecolor='black')

plt.xlabel('Momentum (GeV)')
plt.ylabel('N Events')
plt.xlim(0,600)
plt.yscale('log')
plt.title('Transverse Momentum (p p > H  j, H > S S)', fontweight="bold")
plt.legend()
plt.show()

# %%
hj_transverse_momentum = []
for event in lhe_hjss:
    j = event.particles[-1]
    pt = np.sqrt(j.px**2 + j.py**2)
    hj_transverse_momentum.append(pt)

highWH_transverse_momentum = []
for event in lhe_hjss_highWH:
    j = event.particles[-1]
    pt = np.sqrt(j.px**2 + j.py**2)
    highWH_transverse_momentum.append(pt)

bins = range(0, 601, 40)

# histogram for "p p > H  j, H > S S HIGHWH"
plt.hist(highWH_transverse_momentum, bins = bins, alpha=0.5, color='orange', label='WH = 1', edgecolor='black')

# histogram for "p p > H  j, H > S S"
plt.hist(hj_transverse_momentum, bins = bins, alpha=0.5, color='blue', label='WH = 0,004', edgecolor='black')

plt.xlabel('Momentum (GeV)')
plt.ylabel('N Events')
plt.xlim(0,600)
plt.yscale('log')
plt.title('Transverse Momentum (p p > H  j, H > S S)', fontweight="bold")
plt.legend()
plt.show()

# %%
zj_transverse_momentum = []
for event in lhe_zjvv:
    j = event.particles[-1]
    pt = np.sqrt(j.px**2 + j.py**2)
    zj_transverse_momentum.append(pt)


highMS_transverse_momentum = []
for event in lhe_hjss_highMS:
    j = event.particles[-1]
    pt = np.sqrt(j.px**2 + j.py**2)
    highMS_transverse_momentum.append(pt)

bins = range(0, 601, 40)

# histogram for "p p > H  j, H > S S HIGHMS"
plt.hist(highMS_transverse_momentum, bins = bins, alpha=0.5, color='red', label='MS = 62GeV', edgecolor='black')

# histogram for "p p > Z  j, Z > vm vm~"
plt.hist(zj_transverse_momentum, bins = bins, alpha=0.5, color='blue', label='MV = 0', edgecolor='black')

plt.xlabel('Momentum (GeV)')
plt.ylabel('N Events')
plt.xlim(0,600)
plt.yscale('log')
plt.title('Transverse Momentum', fontweight="bold")
plt.legend()
plt.show()

# %%
zj_transverse_momentum = []
for event in lhe_zjvv:
    j = event.particles[-1]
    pt = np.sqrt(j.px**2 + j.py**2)
    zj_transverse_momentum.append(pt)


lowMS_transverse_momentum = []
for event in lhe_hjss_lowMS:
    j = event.particles[-1]
    pt = np.sqrt(j.px**2 + j.py**2)
    lowMS_transverse_momentum.append(pt)

bins = range(0, 601, 40)

# histogram for "p p > H  j, H > S S LOWMS"
plt.hist(lowMS_transverse_momentum, bins = bins, alpha=0.5, color='red', density=True, label='MS = 1GeV', edgecolor='black')

# histogram for "p p > Z  j, Z > vm vm~"
plt.hist(zj_transverse_momentum, bins = bins, alpha=0.5, color='blue', density=True, label='MV = 0', edgecolor='black')

plt.xlabel('Momentum (GeV)')
plt.ylabel('N Events')
plt.xlim(0,600)
plt.yscale('log')
plt.title('Transverse Momentum', fontweight="bold")
plt.legend()
plt.show()
